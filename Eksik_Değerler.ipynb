# %%
import numpy as np
import pandas as pd
import seaborn as sb
# !pip install missingno

# %%
import missingno as ms

# %%
df = sb.load_dataset("planets")

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
ms.bar(df)
# Out:
# <AxesSubplot:>

# %%
ms.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.dropna(how = "all")
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df["mass"].fillna(df["mass"].mean())
# Out:
# 0        7.100000
# 1        2.210000
# 2        2.600000
# 3       19.400000
# 4       10.500000
#           ...
# 1030     2.638161
# 1031     2.638161
# 1032     2.638161
# 1033     2.638161
# 1034     2.638161
# Name: mass, Length: 1035, dtype: float64

# %%
df.fillna(df.mean()[:])
# Out:
# C:\Users\Sena Bayaz\AppData\Local\Temp\ipykernel_11464\2207373969.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean()[:])
#                method  number  orbital_period       mass  distance  year
# 0     Radial Velocity       1      269.300000   7.100000     77.40  2006
# 1     Radial Velocity       1      874.774000   2.210000     56.95  2008
# 2     Radial Velocity       1      763.000000   2.600000     19.84  2011
# 3     Radial Velocity       1      326.030000  19.400000    110.62  2007
# 4     Radial Velocity       1      516.220000  10.500000    119.47  2009
# ...               ...     ...             ...        ...       ...   ...
# 1030          Transit       1        3.941507   2.638161    172.00  2006
# 1031          Transit       1        2.615864   2.638161    148.00  2007
# ...

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df["mass"].fillna(df.groupby("method")["mass"].transform("mean"))
# Out:
# 0        7.10
# 1        2.21
# 2        2.60
# 3       19.40
# 4       10.50
#         ...
# 1030     1.47
# 1031     1.47
# 1032     1.47
# 1033     1.47
# 1034     1.47
# Name: mass, Length: 1035, dtype: float64

# %%
df = sb.load_dataset("titanic")

# %%
ms.bar(df)
# Out:
# <AxesSubplot:>

# %%
df["age"].fillna(df.groupby("sex")["age"].transform("mean"))
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    27.915709
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
df["deck"].fillna(df["deck"].mode()[0])
# Out:
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C
#       ..
# 886    C
# 887    B
# 888    C
# 889    C
# 890    C
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df_tips = sb.load_dataset("tips")

# %%
df_one_hot = pd.get_dummies(df_tips,columns = ["sex"],prefix=["sex"])

# %%
df_one_hot
# Out:
#      total_bill   tip smoker   day    time  size  sex_Male  sex_Female
# 0         16.99  1.01     No   Sun  Dinner     2         0           1
# 1         10.34  1.66     No   Sun  Dinner     3         1           0
# 2         21.01  3.50     No   Sun  Dinner     3         1           0
# 3         23.68  3.31     No   Sun  Dinner     2         1           0
# 4         24.59  3.61     No   Sun  Dinner     4         0           1
# ..          ...   ...    ...   ...     ...   ...       ...         ...
# 239       29.03  5.92     No   Sat  Dinner     3         1           0
# 240       27.18  2.00    Yes   Sat  Dinner     2         0           1
# 241       22.67  2.00    Yes   Sat  Dinner     2         1           0
# 242       17.82  1.75     No   Sat  Dinner     2         1           0
# 243       18.78  3.00     No  Thur  Dinner     2         0           1
#
# [244 rows x 8 columns]
